# %% [markdown]
# # 4thmay assignment

# %% [markdown]
# Ques1. What is time series and common application of time series analysis?
#
# ans
#
# A time series is a sequence of data points collected or recorded at regular intervals over time . each data in time seried associated with timestamp,making it a variable  tool for analyzing and understanding  how variablw changes over time. Time series  data can be univariate , or multivariate (many variables observed and recorded at each time step).
#
# there are many application but few of them are :
#
# 1. Quality control : In manufacturing and industrial settings, time series analysis can help monitor and control product quality by detecting deviations from expected patterns in production processes.
#
# 2. Forecasting : Time series analysis is widely used for making predictions about future values of a variable based on its historical data. This is valuable in various  fields, such as finance(stock price prediction), economic(GDP forecasting), and weather forecasting.
#
# 3. Anomaly Detection  : Detection unusual or anomalous patterns in time series data is important in various domains, including cybersecurity(instrusion detection), industrial equipment monitoring (predictive maintenance ), and fraud detection .
#
# 4. Stock market analysis : Traders and investors use time series analysis  to analyze historical stock price data, identify trends , and make informed investment decisions.
#
# 5. Healthcare : Time series analysis is applied to monitor and predict patient health , analyze medical equipment data (ECG, EEG readings ) , and track diseases outbreaks.

# %% [markdown]
# Ques 2. What are some common time series patterns, and how can they be identified and interpreted?
#
# ans
#
# Time series data is a sequence of observations or data points collected or recorded at successive points in time,typically at uniform intervals. Analysis time series data involves identifying and understanding common patterns  to make predictions or gain insights. Here are some common patterns  to make predictions or gain insights. Here are some common patterns observed in time series data :
#
#
#
#
# there are four time series components or patterns are:
# 1. trends
# 2. seasonal
# 3. cycle
# 4. noise
#
# 1. trends :
#
# A trend represents a long-term movement or direction in the data. It can be upward (increasing), downward(decreasing), or flat(constant).Trend can be linear or non-linear.
#
# 2. seasonal :
#
# Seasonality refers to repeating patterns or cycles in the data that occur at regular intervals, often associated with calender seasons, months, weeks, or days. Ex - including higher sales during holiday seasons or increased energy consumption during the winter months.
#
#
# 3. cycle :
#
# Cyclical patterns are similar to seasonality but occur at irregular intervals . These patterns typically represent economic  or business cycles and can last for an extended  period. Identifying  cyclical patterns can be more challenging than seasonality.
#
#
#
# 4. noise :
#
# Noise is random variation or irregularity  in the data that cannot be attributed to any specific pattern or trend. It represents the uncertainty or randomness in the data and is typically considered as 'white noise'.
#
# 5. Outliers :
#
# Outliers are data points that deviate significantly from the expected pattern. They can be caused by errors in data collection , unusual events, or anomalies. Detecting and handling outliers is crucial for accurate analysis.

# %% [markdown]
# Q3. How can time series data be preprocessed before applying analysis techniques?
#
#
# ans
#
# Some common preprocessing techniques for time series data include :
#
# - Cleaning  the data : This involves identifying and removing any missing or inconsistent data points, such as data that is out of range or contains errors.
#
# - Resampling the data : This involves changing the frequency or time intervals of the data to a more approriate level, such as changing hourly data to daily data or monthly data.
#
# - Normalizing the data : This involves transforming the data so that it has a mean of zero and a standard deviaiton of one. Normalization can help to reduce the effects of outliers and make it easier to compare data across different time periods.
#
# - Differencing the data : This involves taking the difference between each data point and the previous  data point. Differencing can help to remove trends and seasonalitiy from the data, making it easier to identify patterns and anomalies.
#
# - Smoothing the data : This involves short-term fluctuations from the data by taking a moving average or applying a smoothing function.
# Smoothing can help to identify long-term trends and patterns in the data
#
# - Decomposing the data : This involves separating the data into its trend, seasonality, and residual components. Decomposition can help to identify the underlying patterns and fluctuations in the data.

# %% [markdown]
# Q4. How can time series forecasting be used in business decision-making, and what are some common
# challenges and limitations?
#
#
# Answer
#
#
# Time series forecasting can be a valuable tool for businesses in making informed decisions about the future. By analyzing historical data and identifying patterns and trends, businesses can make predictions about performance and use this information to guide decision-making.
#
# Despite its many benefits, time series forecasting also has some common challenges and limitations. Some of these include :
#
# - Data quality issues : Time series forecasting requires accurate and reliable data, which can be difficult to obtain. Data may be missing, inconsistent, or contain errors, which can lead to inaccurate predicitions.
#
# - Unforeseen events : Time series forecasting is based on historical data, and may not account for unforeseen events such as natural disasters, political upheaval , or changes in consumer behaviour. These events can have a significant impact on future performance, and  may not be accounted for in the forecast.
#
# - Limited scope : Time series forecasting is limited to predicting future performance based on historical data. It may not account for new products or services, changes in the competitive landscape, or other external factors that can impact business performance.
#
# - Complex modells : Time series forecasting models can be complex and difficult to interpret . they may require specialized expertise or software to implement effectively.

# %% [markdown]
# Q5. What is ARIMA modelling, and how can it be used to forecast time series data?
#
#
# Answer
#
# ARIMA(Autogregressive Integrated Moving Average ) is a popular time series modelling techniques used to forecast future values of a time series. ARIMA models are based on the assumptions that the past values of a time series can be used to predict its future values.
#
#
# ARIMA models have three components: autoregression(AR) , differencing(I), and moving average(MA). The AR component represents the relationship between the current value of the time series and its past values, while the MA component represents the relationship between the current value of the time series and its past forecast errors. The I component represents the order of differencing required to make the time series stationary(i.e., removing any trend or seasonality).
#
#
# To apply ARIMA modelling to forecast time series data, the first step is to determine the appropriate values for AR, I, MA components. This can be done using a method called parameter estimation , which involves fitting a series of models with different parameter values to the data and selecting the model with the best fit.
#
# Once the  model parameters have been determined , the next step is to the model to make forecasets. This involves  feeding the historical data into the model and using it to generate a forecast for future values of the time series. The accuracy of the forecast can be evaluated using various metrics , such as mean squared error or mean absolute error.

# %% [markdown]
# Q6. How do Autocorrelation Function (ACF) and Partial Autocorrelation Function (PACF) plots help in
# identifying the order of ARIMA models?
#
# ans
#
#
# Autocorrelation Function (ACF) and Partial Autocorrelation Functio (PACF) plots are graphical tools that can help in identifying the order of ARIMA models.
#
#
# The ACF plot shows the correlation between a time series and its lagged values.
# The PACF plot, on the other hand, shows the correlation between  a time series and its lagged values ,afger removing the effect of any intermediate lags.
#
# To identify the order of an  ARIMA model using ACF and PACf  plots , we can look for specific patterns in the plots. These patterns can help us determine the appropriate values for the AR and MA components of the model.
#
# For example, if the ACF plot shows a significant positive correlation at the first lag, but no significant correlations at any other lags, this suggests that the time series has a strong autoregressive(AR) component of order 1 . Similarly, if the PACF plot shows a significant positive correlation at the first lag, but no significant correlations at any other lags, this suggests that the time series has a strong autoregressive (AR) component of order 1.
#
# If the ACF plot shows a significant negative correlation at the first lag, and significant positive correlations at the second and higher lags that decrease gradually, this suggests that the time series has a strong moving average(MA) component of order 1 . Similarly , if the PACF plot shows a significant negative correaltion at the first lag, and significant positive correaltions at the second and higher lags that decrease gradually , this suggests that the time seris has a strong moving average(MA) component of order 1.
#
# If both ACF and PACF plots show significant correlations at multiple lags, this suggests the time series may require a combination of AR and MA components, and the appropriate order can be determined by analyzing the patterns in the plots.

# %% [markdown]
# Q8. Suppose you have monthly sales data for a retail store for the past three years. Which type of time
# series model would you recommend for forecasting future sales, and why?
#
#
# ans
#
# To recommend the appropriate type of time series model for forecasting future sales, we would need to analyze the properties of the sales data, such as its trend , seasonality , and level of stationarity.
#
# If the sales data exhibits a clear trend and /or seasonality, we may need to use a seasonal ARIMA (SARIMA) model, which is a type of ARIMA model that can handle seasonal patterns in the data. SARIMA models include additional parameters for seasonal differences, seasonal autoregressive (SAR) terms, and seasonal moving average (SMA) terms, and seasonal moving average (SMA) terms.
#
#
# On the other hand, if the sales data exhibits no clear trend or seasonality, we may be able to use a simpler ARIMA  model which can capture the autocorrelation  in the data without explicitly modelling seasonal patterns.
#
#
# Additionally , we may also consider other type of models, such as exponential smoothing models or machine learning , depending on the specific properties of the sales data and the forecasting requirements.

# %% [markdown]
# Q7. What are the assumptions of ARIMA models, and how can they be tested for in practice?
#
# Answer
#
#
# The main assumptions of ARIMA models are :
#
# 1. Stationary  : ARIMA models assume that the time series is stationary, meaning that its statistical properties , such as mean and variance , do not change over time. To test for stationarity , we can use statistical tests like the Augmented Dickey-fuller (ADF) test or the Kwiatkowski-Phillips -Schmidt-Shin (KPSS) test.
#
#
# 2. Linearity : ARIMA models assumes that the relationships between the time series and its lags or forecast errors are linear.This assumption can be tested by examining the residuals of the model and ensuring that they are normally distributed.
#
#
# 3. Independence  :ARIMA models assume that the residuals of the models are independent and identically distributed (i.i.d). We can test for this assumption by examining the autocorrelation  function(ACF) and partial autocorrelation function(PACF) of the residuals.
#
#
# 4. No seasonality : ARIMA models assume that there is no seasonality in the time series . To test for seasonality , we can examine the autocorrelation function at lags that correspond to the seasonal frequency.

# %% [markdown]
# Q9. What are some of the limitations of time series analysis? Provide an example of a scenario where the
# limitations of time series analysis may be particularly relevant.
#
# ans
#
#
#
# While time series analysis can provide valuable insights and forecasts for various applications, there are also several limitations to this approach. Some of the limitations of time series analysis are :
#
#
# - Limited explanatory power : Time series analysis is primarily focused on forecasting future values of a variable based on its past values. While this can be useful for predictin, it may not provide a complete understanding of the underlying causes of the observed patterns.
#
#
# - Sensitivity to outliers and missing data : Time series analysis can be sensitive to outliers and misisng data , which can affect the accuracy of forecasets and lead to incorrect conclusions about the underlying trends and patterns in the data.
#
# - Assumption of stationarity : Many time series models assume that the underlying data is stationary , meaning that its statistical properties do not change over the time. However , in practice , many real -world time series exhibit non-stationarity, which can make it difficult to apply these models.
#
#
# - Difficulty in modelling complex patterns : While time series models can capture simple trends and patterns in the data, they may struggle to capture more complex patterns , such as abrupt changes, long-term trends, or interactions between multiple variables.
#
#
# An example of a scenario where the limitations of time series analysis may be particularly relevant is in the context of financial markets. Financial data oftern exhibits complex and non-stationary patterns, such as sudden changes, in market conditions, long-term trends, and interactions betweeen multiple economic factors. These patterns can be difficult to model using traditional time series approaches and my require more advanced methods, such as machine learning algorithms, to capture the full complexity of the data. Additionally, financial data is often subject to external shocks and events, such as changes in government  policies or unexpected economic developments  , which can mame it challenging to accurately forecast future trends and make informed investment decisions.

# %% [markdown]
# Q10. Explain the difference between a stationary and non-stationary time series. How does the stationarity
# of a time series affect the choice of forecasting model?
#
#
#
#
# answer
#
#
# A time series is a sequence of data points collected or recorded over a period of time. Understanding whether a time series is stationary or non-stationary is crucial in time series analysis and forecasting , as it has a significant impact on the choice of forecasting models and the valididty of statistical assumptions. Here 's an explanation of the difference between stationary and non- stationary time series and their implications for forecasting :
#
# 1. Stationary Time series : A stationary time series is one whose statistical properties do not change over time. In other words, it has constant mean, constant variance, and constant autocorrelation structure(the relationship between data points at different time lags reamins consistent). This constant and consistent behavior, making it easier to model and forecast. Common stationary time series can include financial stock prices after differencing , seasonal data after seasonal differencing , or random noise .
#
# Forecasting stationary time series data are easy because it has constant statistical properties.there is no need to apply transformations or differencing to stablize before modelling.
#
#
# 2. Non-stationary time series: A non-stationary time series is one where the statistical properties change over the time. This typically means that mean, variance , or other characteristics of the data  exhibit trends or fluctuations.It may have trend component, a seasonal component, or both. For example , a time series with an increasing or decreasing trend, or net that exhibits seasonality (regular , repeating patterns),is non-stationary.
# example : many real-world time series data, like economic indicators, often exhibit non-stationary behavior.
#
# forecasting non-stationary time series data can be challenging.it often need to be transformed or differenced to make them stationary before applying traditional models. This process is known as differencing or detrenching. Popular techniques to handle non-stationary data include seasonal decomposition of time series (STL) to separate trend and seasonality , and then applying differencing to remove the trend.
# Once the data is made stationary, you can apply models like ARIMA or its extensions like SARIMA for forecasting.
